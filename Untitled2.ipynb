# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes()
x = np.linspace(0,10,1000)

plt.plot(x, np.sin(x - 3), color='#FF0000', linestyle='dashed', label='rouge')

# %%
# Chanegr la taille de police par défaut
plt.rcParams.update({'font.size': 15})

fig = plt.figure()
ax = plt.axes()
# Couleur spécifiée par son nom, ligne solide
plt.plot(x, np.sin(x - 0), color='blue', linestyle='solid', label='sin(x)')
# Nom court pour la couleur, ligne avec des traits
plt.plot(x, np.sin(x - 1), color='g', linestyle='dashed', label='sin(x-1)')
# Valeur de gris entre 0 et 1, des traits et des points
plt.plot(x, np.sin(x - 2), color='0.75', linestyle='dashdot', label='sin(x-2)')
# Couleur spécifié en RGB, avec des points
plt.plot(x, np.sin(x - 3), color='#FF0000', linestyle='dotted', label='sin(x-3)')

# Les limites des axes, essayez aussi les arguments 'tight' et 'equal' 
# pour voir leur effet
plt.axis([-1, 11, -1.5, 1.5])

# Les labels
plt.title("Fonction sinus retardé")

# La légende est générée à partir de l'argument label de la fonctio
# plot. L'argument loc spécifie le placement de la légende
plt.legend(loc='upper right')

# Titres des axes
ax = ax.set(xlabel='x', ylabel='sin(x)')

# %%
import seaborn as sns
sns.set()

x = np.linspace(0, 10, 100)
y = np.random.randn(100)
plt.plot(x,y)

# %%
sns.distplot(y, kde=True)

# %%
famille_panda = [
    [100, 5  , 20, 80],
    [50 , 2.5, 10, 40],
    [110, 6  , 22, 80],
]

# %%
famille_panda
# Out:
# [[100, 5, 20, 80], [50, 2.5, 10, 40], [110, 6, 22, 80]]

# %%
import pandas as pd
famille_panda_pd = pd.DataFrame(famille_panda, index = ['maman', 'bebe', 'papa'], columns=['pattes', 'poils', 'queue', 'ventre'])
famille_panda_pd
# Out:
#        pattes  poils  queue  ventre
# maman     100    5.0     20      80
# bebe       50    2.5     10      40
# papa      110    6.0     22      80

# %%
famille_panda_pd.ventre
famille_panda_pd["ventre"].values
# Out:
# array([80, 40, 80])

# %%
for indrow, indcolumn in famille_panda_pd.iterrows():
    print('Je suis '+indrow)
    print(indcolumn)
# Out:
# Je suis maman
# pattes    100.0
# poils       5.0
# queue      20.0
# ventre     80.0
# Name: maman, dtype: float64
# Je suis bebe
# pattes    50.0
# poils      2.5
# queue     10.0
# ventre    40.0
# Name: bebe, dtype: float64
# Je suis papa
# pattes    110.0
# poils       6.0
# queue      22.0
# ventre     80.0
# Name: papa, dtype: float64

# %%
famille_panda_pd.loc['maman']
# Out:
# pattes    100.0
# poils       5.0
# queue      20.0
# ventre     80.0
# Name: maman, dtype: float64

# %%
famille_panda_pd[~ (famille_panda_pd.ventre >= 80)]
# Out:
#       pattes  poils  queue  ventre
# bebe      50    2.5     10      40

# %%
quelques_pandas = pd.DataFrame([[105,4,19,80],[100,5,20,80]],      # deux nouveaux pandas
                               columns = famille_panda_pd.columns) 
                               # même colonnes que famille_panda_df
tous_les_pandas = famille_panda_pd.append(quelques_pandas)
tous_les_pandas
# Out:
#        pattes  poils  queue  ventre
# maman     100    5.0     20      80
# bebe       50    2.5     10      40
# papa      110    6.0     22      80
# 0         105    4.0     19      80
# 1         100    5.0     20      80

# %%
tous_les_pandas.drop_duplicates()
# Out:
#        pattes  poils  queue  ventre
# maman     100    5.0     20      80
# bebe       50    2.5     10      40
# papa      110    6.0     22      80
# 0         105    4.0     19      80

# %%
tous_les_pandas
# Out:
#        pattes  poils  queue  ventre
# maman     100    5.0     20      80
# bebe       50    2.5     10      40
# papa      110    6.0     22      80
# 0         105    4.0     19      80
# 1         100    5.0     20      80
